# %%
from sklearn import datasets, metrics
import tensorflow as tf
import numpy as np
from sklearn.cross_validation import train_test_split
# %matplotlib inline

# %%
# Data set of IRIS
iris = datasets.load_iris()

# Load datasets and split them for training and testing
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target)


####### TENSORFLOW #####

# Here is tensorflow's syntac for defining features.
# We must specify that all features have real-value data
feature_columns = [tf.contrib.layers.real_valued_column("", dimension=4)]

optimizer = tf.train.GradientDescentOptimizer(learning_rate=.1)


# Build a linear classifier (logistic regression)
# note we have to tell tensorfow the number of classes we are looking for
classifier = tf.contrib.learn.LinearClassifier(feature_columns=feature_columns,
                                               optimizer=optimizer,
                                            n_classes=3)

# Fit model. Uses error optimization techniques like stochastic gradient descent
classifier.fit(x=X_train,
               y=y_train,
               steps=1000)  # number of iterations

# Evaluate accuracy.
accuracy_score = classifier.evaluate(x=X_test,
                                     y=y_test)["accuracy"]
print('Accuracy: {0:f}'.format(accuracy_score))

# Classify two new flower samples.
new_samples = np.array(
    [[6.4, 3.2, 4.5, 1.5], [5.8, 3.1, 5.0, 1.7]], dtype=float)
y = classifier.predict(new_samples)
print('Predictions: {}'.format(str(y)))
# Out:
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/1t/3fvf6cyx17s0mnkw0s9zj6ph0000gn/T/tmpoyC0rr
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_num_ps_replicas': 0, '_keep_checkpoint_max': 5, '_tf_random_seed': None, '_task_type': None, '_environment': 'local', '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x1236ab950>, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_task_id': 0, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_evaluation_master': '', '_keep_checkpoint_every_n_hours': 10000, '_master': ''}
# WARNING:tensorflow:From <ipython-input-58-c5462b8d2586>:26: calling fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-58-c5462b8d2586>:26: calling fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:From //anaconda/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:1362: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/1t/3fvf6cyx17s0mnkw0s9zj6ph0000gn/T/tmpoyC0rr/model.ckpt.
# INFO:tensorflow:loss = 1.09861, step = 1
# INFO:tensorflow:global_step/sec: 655.673
# INFO:tensorflow:loss = 0.378662, step = 101
# INFO:tensorflow:global_step/sec: 522.624
# INFO:tensorflow:loss = 0.249742, step = 201
# INFO:tensorflow:global_step/sec: 443.261
# INFO:tensorflow:loss = 0.207507, step = 301
# INFO:tensorflow:global_step/sec: 490.374
# INFO:tensorflow:loss = 0.181009, step = 401
# INFO:tensorflow:global_step/sec: 475.559
# INFO:tensorflow:loss = 0.162752, step = 501
# INFO:tensorflow:global_step/sec: 682.663
# INFO:tensorflow:loss = 0.149353, step = 601
# INFO:tensorflow:global_step/sec: 652.746
# INFO:tensorflow:loss = 0.139059, step = 701
# INFO:tensorflow:global_step/sec: 686.134
# INFO:tensorflow:loss = 0.130875, step = 801
# INFO:tensorflow:global_step/sec: 616.31
# INFO:tensorflow:loss = 0.124193, step = 901
# INFO:tensorflow:Saving checkpoints for 1000 into /var/folders/1t/3fvf6cyx17s0mnkw0s9zj6ph0000gn/T/tmpoyC0rr/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.11867.
# WARNING:tensorflow:From <ipython-input-58-c5462b8d2586>:30: calling evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-58-c5462b8d2586>:30: calling evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:From //anaconda/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:1362: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-03-17-02:19:15
# INFO:tensorflow:Finished evaluation at 2017-03-17-02:19:16
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.973684, auc = 0.998615, global_step = 1000, loss = 0.163593
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# Accuracy: 0.973684
# WARNING:tensorflow:From //anaconda/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/linear.py:474: calling predict (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# Predictions: <generator object _as_iterable at 0x11f4c4960>

# %%
classifier.__dict__
# Out:
# {'_config': <tensorflow.contrib.learn.python.learn.estimators.run_config.RunConfig at 0x12095ee10>,
#  '_device_fn': None,
#  '_feature_columns': (_RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None),),
#  '_feature_engineering_fn': <function tensorflow.contrib.learn.python.learn.estimators.estimator._identity_feature_engineering_fn>,
#  '_features_info': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False),
#  '_graph': <tensorflow.python.framework.ops.Graph at 0x123694950>,
#  '_labels_info': TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False),
#  '_model_dir': '/var/folders/1t/3fvf6cyx17s0mnkw0s9zj6ph0000gn/T/tmpoyC0rr',
#  '_model_fn': <function tensorflow.contrib.learn.python.learn.estimators.linear._linear_model_fn>,
#  '_optimizer': <tensorflow.python.training.gradient_descent.GradientDescentOptimizer at 0x123953b10>,
#  'params': {'feature_columns': [_RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)],
#   'gradient_clip_norm': None,
#   'head': <tensorflow.contrib.learn.python.learn.estimators.head._MultiClassHead at 0x1239533d0>,
#   'joint_weights': False,
#   'optimizer': <tensorflow.python.training.gradient_descent.GradientDescentOptimizer at 0x123953b10>}}

# %%
# Make a Deep Neural Network (DNN)

# %%
# Data sets
iris = datasets.load_iris()

# Load datasets.
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target)

# Specify that all features have real-value data
feature_columns = [tf.contrib.layers.real_valued_column("", dimension=4)]

optimizer = tf.train.GradientDescentOptimizer(learning_rate=.1)


# Build 3 layer DNN with 10, 20, 10 units respectively.
classifier = tf.contrib.learn.DNNClassifier(feature_columns=feature_columns,
                                            hidden_units=[10, 20, 10],
                                            optimizer=optimizer,
                                            n_classes=3)

# Fit model.
classifier.fit(x=X_train,
               y=y_train,
               steps=2000)

# Evaluate accuracy.
accuracy_score = classifier.evaluate(x=X_test,
                                     y=y_test)["accuracy"]
print('Accuracy: {0:f}'.format(accuracy_score))

# Classify two new flower samples.
new_samples = np.array(
    [[6.4, 3.2, 4.5, 1.5], [5.8, 3.1, 5.0, 1.7]], dtype=float)
y = classifier.predict(new_samples)
print('Predictions: {}'.format(str(y)))
# Out:
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/1t/3fvf6cyx17s0mnkw0s9zj6ph0000gn/T/tmpfONrZ_
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_num_ps_replicas': 0, '_keep_checkpoint_max': 5, '_tf_random_seed': None, '_task_type': None, '_environment': 'local', '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x124210c10>, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_task_id': 0, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_evaluation_master': '', '_keep_checkpoint_every_n_hours': 10000, '_master': ''}
# WARNING:tensorflow:From <ipython-input-60-65d8101680ea>:22: calling fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-60-65d8101680ea>:22: calling fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:From //anaconda/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:1362: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/1t/3fvf6cyx17s0mnkw0s9zj6ph0000gn/T/tmpfONrZ_/model.ckpt.
# INFO:tensorflow:loss = 1.16785, step = 1
# INFO:tensorflow:global_step/sec: 608.602
# INFO:tensorflow:loss = 0.411345, step = 101
# INFO:tensorflow:global_step/sec: 591.254
# INFO:tensorflow:loss = 0.165682, step = 201
# INFO:tensorflow:global_step/sec: 526.992
# INFO:tensorflow:loss = 0.231522, step = 301
# INFO:tensorflow:global_step/sec: 612.216
# INFO:tensorflow:loss = 0.0939758, step = 401
# INFO:tensorflow:global_step/sec: 593.173
# INFO:tensorflow:loss = 0.115116, step = 501
# INFO:tensorflow:global_step/sec: 497.413
# INFO:tensorflow:loss = 0.100647, step = 601
# INFO:tensorflow:global_step/sec: 579.639
# INFO:tensorflow:loss = 0.102213, step = 701
# INFO:tensorflow:global_step/sec: 562.256
# INFO:tensorflow:loss = 0.0870413, step = 801
# INFO:tensorflow:global_step/sec: 409.548
# INFO:tensorflow:loss = 0.0702913, step = 901
# INFO:tensorflow:global_step/sec: 443.605
# INFO:tensorflow:loss = 0.0808012, step = 1001
# INFO:tensorflow:global_step/sec: 497.851
# INFO:tensorflow:loss = 0.0693016, step = 1101
# INFO:tensorflow:global_step/sec: 442.018
# INFO:tensorflow:loss = 0.0612699, step = 1201
# INFO:tensorflow:global_step/sec: 452.374
# INFO:tensorflow:loss = 0.0982593, step = 1301
# INFO:tensorflow:global_step/sec: 481.937
# INFO:tensorflow:loss = 0.0698069, step = 1401
# INFO:tensorflow:global_step/sec: 572.495
# INFO:tensorflow:loss = 0.0625486, step = 1501
# INFO:tensorflow:global_step/sec: 486.034
# INFO:tensorflow:loss = 0.0550134, step = 1601
# INFO:tensorflow:global_step/sec: 428.295
# INFO:tensorflow:loss = 0.150856, step = 1701
# INFO:tensorflow:global_step/sec: 452.407
# INFO:tensorflow:loss = 0.0660117, step = 1801
# INFO:tensorflow:global_step/sec: 381.965
# INFO:tensorflow:loss = 0.0753338, step = 1901
# INFO:tensorflow:Saving checkpoints for 2000 into /var/folders/1t/3fvf6cyx17s0mnkw0s9zj6ph0000gn/T/tmpfONrZ_/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0515502.
# WARNING:tensorflow:From <ipython-input-60-65d8101680ea>:26: calling evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-60-65d8101680ea>:26: calling evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:From //anaconda/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:1362: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-03-17-02:19:26
# INFO:tensorflow:Finished evaluation at 2017-03-17-02:19:27
# INFO:tensorflow:Saving dict for global step 2000: accuracy = 1.0, auc = 1.0, global_step = 2000, loss = 0.00700016
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# Accuracy: 1.000000
# WARNING:tensorflow:From //anaconda/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/dnn.py:374: calling predict (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# Predictions: <generator object <genexpr> at 0x124377140>

# %%
classifier.__dict__
# Out:
# {'_config': <tensorflow.contrib.learn.python.learn.estimators.run_config.RunConfig at 0x12436d490>,
#  '_device_fn': None,
#  '_enable_centered_bias': False,
#  '_feature_columns': (_RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None),),
#  '_feature_engineering_fn': <function tensorflow.contrib.learn.python.learn.estimators.estimator._identity_feature_engineering_fn>,
#  '_features_info': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False),
#  '_graph': <tensorflow.python.framework.ops.Graph at 0x123fa1c10>,
#  '_hidden_units': [10, 20, 10],
#  '_labels_info': TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False),
#  '_model_dir': '/var/folders/1t/3fvf6cyx17s0mnkw0s9zj6ph0000gn/T/tmpfONrZ_',
#  '_model_fn': <function tensorflow.contrib.learn.python.learn.estimators.dnn._dnn_model_fn>,
#  'params': {'activation_fn': <function tensorflow.python.ops.gen_nn_ops.relu>,
#   'dropout': None,
#   'embedding_lr_multipliers': None,
#   'feature_columns': (_RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None),),
#   'gradient_clip_norm': None,
#   'head': <tensorflow.contrib.learn.python.learn.estimators.head._MultiClassHead at 0x123fa1fd0>,
#   'hidden_units': [10, 20, 10],
#   'input_layer_min_slice_size': None,
#   'optimizer': <tensorflow.python.training.gradient_descent.GradientDescentOptimizer at 0x123fa10d0>}}

# %%
# Data sets
iris = datasets.load_iris()

# Load datasets.
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target)

# Specify that all features have real-value data
feature_columns = [tf.contrib.layers.real_valued_column("", dimension=4)]

optimizer = tf.train.GradientDescentOptimizer(learning_rate=.1)


# Build 3 layer DNN with 10, 20, 10 units respectively.
classifier = tf.contrib.learn.DNNClassifier(feature_columns=feature_columns,
                                            hidden_units=[10, 20, 20, 10],
                                            optimizer=optimizer,
                                            n_classes=3)

# Fit model.
classifier.fit(x=X_train,
               y=y_train,
               steps=2000)

# Evaluate accuracy.
accuracy_score = classifier.evaluate(x=X_test,
                                     y=y_test)["accuracy"]
print('Accuracy: {0:f}'.format(accuracy_score))

# Classify two new flower samples.
new_samples = np.array(
    [[6.4, 3.2, 4.5, 1.5], [5.8, 3.1, 5.0, 1.7]], dtype=float)
y = classifier.predict(new_samples)
print('Predictions: {}'.format(str(y)))
# Out:
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/1t/3fvf6cyx17s0mnkw0s9zj6ph0000gn/T/tmpEPnvvs
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_num_ps_replicas': 0, '_keep_checkpoint_max': 5, '_tf_random_seed': None, '_task_type': None, '_environment': 'local', '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x1239b26d0>, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_task_id': 0, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_evaluation_master': '', '_keep_checkpoint_every_n_hours': 10000, '_master': ''}
# WARNING:tensorflow:From <ipython-input-62-ddc867aed2de>:22: calling fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-62-ddc867aed2de>:22: calling fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:From //anaconda/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:1362: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/1t/3fvf6cyx17s0mnkw0s9zj6ph0000gn/T/tmpEPnvvs/model.ckpt.
# INFO:tensorflow:loss = 1.26649, step = 1
# INFO:tensorflow:global_step/sec: 523.613
# INFO:tensorflow:loss = 0.57512, step = 101
# INFO:tensorflow:global_step/sec: 414.86
# INFO:tensorflow:loss = 0.159742, step = 201
# INFO:tensorflow:global_step/sec: 534.756
# INFO:tensorflow:loss = 0.356217, step = 301
# INFO:tensorflow:global_step/sec: 487.562
# INFO:tensorflow:loss = 0.0589735, step = 401
# INFO:tensorflow:global_step/sec: 555.472
# INFO:tensorflow:loss = 0.0590412, step = 501
# INFO:tensorflow:global_step/sec: 554.45
# INFO:tensorflow:loss = 0.0568216, step = 601
# INFO:tensorflow:global_step/sec: 564.404
# INFO:tensorflow:loss = 0.0475476, step = 701
# INFO:tensorflow:global_step/sec: 470.883
# INFO:tensorflow:loss = 0.0438114, step = 801
# INFO:tensorflow:global_step/sec: 491.045
# INFO:tensorflow:loss = 0.0442497, step = 901
# INFO:tensorflow:global_step/sec: 553.382
# INFO:tensorflow:loss = 0.0388471, step = 1001
# INFO:tensorflow:global_step/sec: 546.052
# INFO:tensorflow:loss = 0.0490505, step = 1101
# INFO:tensorflow:global_step/sec: 544.368
# INFO:tensorflow:loss = 0.0375605, step = 1201
# INFO:tensorflow:global_step/sec: 540.264
# INFO:tensorflow:loss = 0.0358194, step = 1301
# INFO:tensorflow:global_step/sec: 496.956
# INFO:tensorflow:loss = 0.0401188, step = 1401
# INFO:tensorflow:global_step/sec: 499.605
# INFO:tensorflow:loss = 0.037115, step = 1501
# INFO:tensorflow:global_step/sec: 409.099
# INFO:tensorflow:loss = 0.0343208, step = 1601
# INFO:tensorflow:global_step/sec: 535.314
# INFO:tensorflow:loss = 0.0341907, step = 1701
# INFO:tensorflow:global_step/sec: 532.964
# INFO:tensorflow:loss = 0.0385141, step = 1801
# INFO:tensorflow:global_step/sec: 544.292
# INFO:tensorflow:loss = 0.105683, step = 1901
# INFO:tensorflow:Saving checkpoints for 2000 into /var/folders/1t/3fvf6cyx17s0mnkw0s9zj6ph0000gn/T/tmpEPnvvs/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0406263.
# WARNING:tensorflow:From <ipython-input-62-ddc867aed2de>:26: calling evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-62-ddc867aed2de>:26: calling evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:From //anaconda/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:1362: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-03-17-02:19:42
# INFO:tensorflow:Finished evaluation at 2017-03-17-02:19:42
# INFO:tensorflow:Saving dict for global step 2000: accuracy = 0.973684, auc = 0.996537, global_step = 2000, loss = 0.101998
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# Accuracy: 0.973684
# WARNING:tensorflow:From //anaconda/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/dnn.py:374: calling predict (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# Predictions: <generator object <genexpr> at 0x1219672d0>

# %%
# HOT DAMN SLOW DOWN TENSORFLOW, what is happening here?

#1. what if I run it again?
#2. why might the accuracy be very high?

# %% [markdown]
# Deep Neural Network vs Convulutional Neural Network
#
# Deep Net
# <img src="http://cs231n.github.io/assets/nn1/neural_net2.jpeg">
#
# <br>
# <br>
# Conv Net
# <img src="http://cs231n.github.io/assets/cnn/cnn.jpeg">

# %%
n = np.array([])

np.append(n, 2)
# Out:
# array([ 2.])

# %%
# Object Detection

# %%
from glob import glob
from pylab import imread, imsave, subplot, imshow, title, gray, figure, show, NullLocator
from numpy import mean, cov, dot, linalg, size, argsort
import PIL
from PIL import Image
from keras.utils import np_utils

# %%
# read in the images

X, y = np.array([]), np.array([])
y = []
code_to_target = {}
num_classes = 0
size = 32, 32
for folder in glob('objects/*'):
    name_of_object= folder.split('/')[-1]
    
    if name_of_object not in ['Motorbikes', 'octopus', 'accordion', 'stop_sign']:
        continue
    code_to_target[num_classes] = name_of_object
    print name_of_object
    for f in glob(folder+'/*'):  # only take the first 20 images
        img = Image.open(f)
        img = img.resize(size, Image.ANTIALIAS) # resize image to 32 by 32 for ease
        img.save(f, "JPEG") # resave the image back to the folder
        row = imread(f) # load an image  # load it into numpy
        row = np.expand_dims(row, axis=0)
        if X.shape[0] != 0 and row.shape == (1, 32, 32, 3):
#             y = np.vstack((y, i))
            y.append(num_classes)
            X = np.vstack((X,row))
        elif X.shape[0] == 0:
            X = row
            y.append(num_classes)
    num_classes += 1

# %%
y = np.array(y)

# %%
X.shape, y.shape
# Out:
# ((0,), (0,))

# %%
# normalize inputs from 0-255 to 0.0-1.0
X = X.astype('float32')
X = X / 255.0

y = np_utils.to_categorical(y)
num_classes = y.shape[1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-9414d3b3f2c8> in <module>()
#       3 X = X / 255.0
#       4
# ----> 5 y = np_utils.to_categorical(y)
#       6 num_classes = y.shape[1]
#
# //anaconda/lib/python2.7/site-packages/keras/utils/np_utils.pyc in to_categorical(y, num_classes)
#      20     y = np.array(y, dtype='int').ravel()
#      21     if not num_classes:
# ---> 22         num_classes = np.max(y) + 1
#      23     n = y.shape[0]
#      24     categorical = np.zeros((n, num_classes))
#
# //anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in amax(a, axis, out, keepdims)
#    2266     else:
#    2267         return _methods._amax(a, axis=axis,
# -> 2268                               out=out, keepdims=keepdims)
#    2269
#    2270
#
# //anaconda/lib/python2.7/site-packages/numpy/core/_methods.pyc in _amax(a, axis, out, keepdims)
#      24 # small reductions
#      25 def _amax(a, axis=None, out=None, keepdims=False):
# ---> 26     return umr_maximum(a, axis, None, out, keepdims)
#      27
#      28 def _amin(a, axis=None, out=None, keepdims=False):
#
# ValueError: zero-size array to reduction operation maximum which has no identity

# %%
X.shape, y.shape
# Out:
# ((0,), (0,))

# %%
X[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-71-1d61f6e5db90> in <module>()
# ----> 1 X[0]
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
# Load datasets.
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
print X_train.shape
print X_test.shape
print y_train.shape
print y_test.shape
# Out:
# (0,)
# (0,)
# (0,)
# (0,)

# %%
# Simple CNN model for CIFAR-10
import numpy
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.constraints import maxnorm
from keras.optimizers import SGD
from keras.layers.convolutional import Convolution2D
from keras.layers.convolutional import MaxPooling2D
from keras.utils import np_utils
from keras import backend as K
K.set_image_dim_ordering('th')

# %%
# create the model
model = Sequential()
model.add(Convolution2D(32, 3, 3, input_shape=(32, 32, 3), border_mode='same', activation='relu', W_constraint=maxnorm(3)))
model.add(Dropout(0.2))
model.add(Convolution2D(32, 3, 3, activation='relu', border_mode='same', W_constraint=maxnorm(3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(512, activation='relu', W_constraint=maxnorm(3)))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
# Compile model
epochs = 25
lrate = 0.01
decay = lrate/epochs
sgd = SGD(lr=lrate, momentum=0.9, decay=decay, nesterov=False)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 32, 32, 3)         9248
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 32, 3)         9248
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 32, 16, 1)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 0)                 0
# =================================================================
# Total params: 281,152.0
# Trainable params: 281,152.0
# Non-trainable params: 0.0
# _________________________________________________________________
# None

# %%
# Fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), nb_epoch=epochs, batch_size=32)
# Final evaluation of the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-397f6f4bbc73> in <module>()
#       1 # Fit the model
# ----> 2 model.fit(X_train, y_train, validation_data=(X_test, y_test), nb_epoch=epochs, batch_size=32)
#       3 # Final evaluation of the model
#       4 scores = model.evaluate(X_test, y_test, verbose=0)
#       5 print("Accuracy: %.2f%%" % (scores[1]*100))
#
# //anaconda/lib/python2.7/site-packages/keras/models.pyc in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#     843                               class_weight=class_weight,
#     844                               sample_weight=sample_weight,
# --> 845                               initial_epoch=initial_epoch)
#     846
#     847     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# //anaconda/lib/python2.7/site-packages/keras/engine/training.pyc in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#    1403             class_weight=class_weight,
#    1404             check_batch_axis=False,
# -> 1405             batch_size=batch_size)
#    1406         # prepare validation data
#    1407         if validation_data:
#
# //anaconda/lib/python2.7/site-packages/keras/engine/training.pyc in _standardize_user_data(self, x, y, sample_weight, class_weight, check_batch_axis, batch_size)
#    1293                                     self._feed_input_shapes,
#    1294                                     check_batch_axis=False,
# -> 1295                                     exception_prefix='model input')
#    1296         y = _standardize_input_data(y, self._feed_output_names,
#    1297                                     output_shapes,
#
# //anaconda/lib/python2.7/site-packages/keras/engine/training.pyc in _standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     119                                  ' to have ' + str(len(shapes[i])) +
#     120                                  ' dimensions, but got array with shape ' +
# --> 121                                  str(array.shape))
#     122             for j, (dim, ref_dim) in enumerate(zip(array.shape, shapes[i])):
#     123                 if not j and not check_batch_axis:
#
# ValueError: Error when checking model input: expected conv2d_5_input to have 4 dimensions, but got array with shape (0, 1)

# %%
# Ideally we would train more and larger hidden layers, but the idea will come across

# %%
# I found this gem of an image on Google Images

# %%
url = 'accordion_band.jpg'
image = imread(url) # load an image
image.shape
# Out:
# (707, 1280, 3)

# %%
imshow(image)  # such class

# %%
import random
random_x_coordinate = random.choice(range(1,image.shape[0]-128))
random_y_coordinate = random.choice(range(1,image.shape[0]-128))  # choose a random starting point
subset = image[random_y_coordinate:random_y_coordinate+128,random_x_coordinate:random_x_coordinate+128,]
imshow(subset)

# %%
img = Image.fromarray(subset, 'RGB')
img = img.resize(size, Image.ANTIALIAS) # resize image to 32 by 32 for ease
img.save(f, "JPEG") # resave the image back to the folder
row = imread(f) # load an image  # load it into numpy
row = np.expand_dims(row, axis=0)
img
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-e3087736c1f7> in <module>()
#       1 img = Image.fromarray(subset, 'RGB')
#       2 img = img.resize(size, Image.ANTIALIAS) # resize image to 32 by 32 for ease
# ----> 3 img.save(f, "JPEG") # resave the image back to the folder
#       4 row = imread(f) # load an image  # load it into numpy
#       5 row = np.expand_dims(row, axis=0)
#
# NameError: name 'f' is not defined

# %%
row = row.astype('float32')
row = row / 255.0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-5f40df8c6ab8> in <module>()
# ----> 1 row = row.astype('float32')
#       2 row = row / 255.0
#
# NameError: name 'row' is not defined

# %%
model.predict(row)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-58b2baf81ecc> in <module>()
# ----> 1 model.predict(row)
#
# NameError: name 'row' is not defined

# %%
np.argmax(model.predict(row))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-f0182dd8e416> in <module>()
# ----> 1 np.argmax(model.predict(row))
#
# NameError: name 'row' is not defined

# %%
code_to_target[np.argmax(model.predict(row))]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-1659aad2e2d4> in <module>()
# ----> 1 code_to_target[np.argmax(model.predict(row))]
#
# NameError: name 'row' is not defined

# %%
url = 'stop.jpg'
image = imread(url) # load an image
image.shape
# Out:
# (1200, 1800, 3)

# %%
imshow(image)

# %%
import random
random_x_coordinate = random.choice(range(1,image.shape[0]))
random_y_coordinate = random.choice(range(1,image.shape[0]))  # choose a random starting point
random_x_coordinate, random_y_coordinate = 400, 50
subset = image[random_y_coordinate:random_y_coordinate+128,random_x_coordinate:random_x_coordinate+128,]
print random_x_coordinate, random_y_coordinate
imshow(subset)
# Out:
# 400 50

# %%
f = 'here.jpg'
img = Image.fromarray(subset, 'RGB')
img = img.resize(size, Image.ANTIALIAS) # resize image to 32 by 32 for ease
img.save(f, "JPEG") # resave the image back to the folder
row = imread(f) # load an image  # load it into numpy
row = np.expand_dims(row, axis=0)
img
# Out:
# <PIL.Image.Image image mode=RGB size=32x32 at 0x123694350>

# %%
row = row.astype('float32')
row = row / 255.0

# %%
code_to_target[np.argmax(model.predict(row))], max(model.predict(row)[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-6803095e44db> in <module>()
# ----> 1 code_to_target[np.argmax(model.predict(row))], max(model.predict(row)[0])
#
# //anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in argmax(a, axis, out)
#     972     except AttributeError:
#     973         return _wrapit(a, 'argmax', axis, out)
# --> 974     return argmax(axis, out)
#     975
#     976
#
# ValueError: attempt to get argmax of an empty sequence

# %%
def predict_window(x_coordinate, y_coordinate, window_size=128, resize_to=(32,32)):
    subset = image[y_coordinate:y_coordinate+window_size,x_coordinate:x_coordinate+window_size,]
    img = Image.fromarray(subset, 'RGB')
    img = img.resize(size, Image.ANTIALIAS) # resize image to 32 by 32 for ease
    f = 'here.jpg'
    img.save(f, "JPEG") # resave the image back to the folder
    row = imread(f) # load an image  # load it into numpy
    row = np.expand_dims(row, axis=0)
    imshow(img)
    row = row.astype('float32')
    row = row / 255.0
    proba = max(model.predict(row)[0])
    return code_to_target[np.argmax(model.predict(row))], proba

# %%
predict_window(350,50,400)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-110-031e11f5ffac> in <module>()
# ----> 1 predict_window(350,50,400)
#
# <ipython-input-109-6c65d401564b> in predict_window(x_coordinate, y_coordinate, window_size, resize_to)
#      10     row = row.astype('float32')
#      11     row = row / 255.0
# ---> 12     proba = max(model.predict(row)[0])
#      13     return code_to_target[np.argmax(model.predict(row))], proba
#
# ValueError: max() arg is an empty sequence

# %%
window_size = 400
step = 50
threshold = .9999
found = []
for x in range(1,image.shape[0]-window_size, step):
    for y in range(1,image.shape[1]-window_size, step):
        try:
            prediction, proba = predict_window(x,y,window_size)
            if proba >= threshold:
                found.append((x, y, window_size, prediction, proba))
        except:
            pass

# %%
found
# Out:
# []

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import numpy as np


# Create figure and axes
fig,ax = plt.subplots(1)

# Display the image
ax.imshow(image)

# Create a Rectangle patch
for f in found:
    rect = patches.Rectangle((f[0],f[1]),f[2],f[2],linewidth=1,edgecolor='r',facecolor='none')
    ax.add_patch(rect)

# Add the patch to the Axes


plt.show()

# %%
def magic(url, window_size=200, step=50, threshold=.99):
    image = imread(url) # load an image
    image.shape
#     window_size = 200
#     step = 50
#     threshold = .999
    found = []
    def predict_window(image, x_coordinate, y_coordinate, window_size=128, resize_to=(32,32)):
        subset = image[y_coordinate:y_coordinate+window_size,x_coordinate:x_coordinate+window_size,]
        img = Image.fromarray(subset, 'RGB')
        img = img.resize(size, Image.ANTIALIAS) # resize image to 32 by 32 for ease
        f = 'here.jpg'
        img.save(f, "JPEG") # resave the image back to the folder
        row = imread(f) # load an image  # load it into numpy
        row = np.expand_dims(row, axis=0)
        row = row.astype('float32')
        row = row / 255.0
        proba = max(model.predict(row)[0])
        return code_to_target[np.argmax(model.predict(row))], proba
    for x in range(1,image.shape[0]-window_size, step):
        for y in range(1,image.shape[1]-window_size, step):
            try:
                prediction, proba = predict_window(image, x,y,window_size)
                if proba >= threshold:
                    found.append((x, y, window_size, prediction, proba))
            
            except Exception as e:
                pass
    # Create figure and axes
    fig,ax = plt.subplots(1)

    # Display the image
    ax.imshow(image)
    print found
    # Create a Rectangle patch
    for f in found:
        rect = patches.Rectangle((f[0],f[1]),f[2],f[2],linewidth=1,edgecolor='r',facecolor='none')
        ax.add_patch(rect)

    # Add the patch to the Axes


    plt.show()

# %%
url = 'accordion_band.jpg'
magic(url=url, window_size=300, step=50, threshold=.99)
# Out:
# []

# %%
url = 'stop.jpg'
magic(url, window_size=400, step=50, threshold=.998)
# Out:
# []

# %%
url = 'motor.jpg'
magic(url, window_size=350, step=50, threshold=.995)
# Out:
# []
